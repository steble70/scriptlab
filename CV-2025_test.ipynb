# %% [markdown]
# # **IT kompetenser**
# #### © 2025 av Stefan Blecko, `070-6445868`
# **[LinkedIn](https://www.linkedin.com/in/stefan70/recent-activity/all/) | [Arbetsomdöme](https://github.com/steble70/scriptlab/blob/master/Blecko_Stefan_Arbetsbetyg.pdf) | Referens: [Peter Mwaka](https://www.linkedin.com/in/peter-mwaka-23ab0915?lipi=urn%3Ali%3Apage%3Ad_flagship3_profile_view_base_contact_details%3BuqCZBsuNRmCXcZ7ilYV97A%3D%3D) |
# Portfolio: [GitHub](https://github.com/steble70/scriptlab) | [IT kompetenser 2](https://github.com/steble70/scriptlab/blob/master/Blecko_Stefan_kompetenser2.ipynb)**
#
# ---

# %%
import os
import random
import matplotlib.pyplot as plt
from IPython.display import SVG, display

# %%
# %matplotlib inline

# %%
# Exempel av Stefan Blecko
def competence(**skills):
    x = skills.keys()
    y = skills.values()
    plt.ylim(0, 5)
    plt.bar(x, y)
    plt.ylabel('Kunskapsnivå')
    plt.xlabel('Certifierad i Microsoft MS-900 och SC-900.', 
               fontdict={'fontsize': 8}, labelpad=10)
    plt.show()

competence(Operativsystem=3, Programmering=2, Support=4.5, Molntjänster=3)

# %% [markdown]
# ### **Kunskaper om operativsystem**

# %%
# !pwsh -nol -noni -nop -f Get-ComputerInventory.ps1
# Out:
# Tillverkare        : Acer
# Modell             : NC-ES1-131-C8KH
# BIOS               : Insyde Corp.
# BIOS version       : ACRSYS - 3
# Windows version    : Microsoft Windows 10 Home
# Windows Produkt-ID : 00326-10000-00000-AA635
# Processor          : Intel(R) Celeron(R) CPU  N3050  @ 1.60GHz
# RAM                : 2
# Ljudkort           : {Realtek High Definition Audio, Intel(R) bildsk„rmsljud}
# Grafikkort         : Intel(R) HD Graphics
# H†rddisk           : 29
# N„tverkskort       : Qualcomm Atheros AR956x Wireless Network Adapter
# MAC adress         : B8:86:87:D2:CF:BF
# Hostname           : DESKTOP-F24MLRV
# DHCP server        : 10.128.128.128
# DNS Domain         :
# IP-adress          : {10.150.109.221, fe80::a985:d20d:aef3:74c6}
# Default Gateway    : {10.128.128.128}
# Subn„tmask         : {255.0.0.0, 64}

# %% [markdown]
# ### **Programmering**

# %%
display(SVG('multiplikationstabellen.svg'))

# %% [markdown]
# ### **Erfarenheter av IT-support**

# %%
# Exempel av Stefan Blecko
def support(**skills):
    x = skills.keys()
    y = skills.values()
    plt.ylim(0, 5)
    plt.bar(x, y, color='purple')
    plt.ylabel('Kunskapsnivå')
    plt.show()

support(AD=4, Serveruppd=3, CMS=2.5, Remote_verktyg=4)
