# %% [markdown]
# # **Vibe coding med Microsoft Copilot**
# #### © 2025 Stefan Blecko, 070-6445868
# [LinkedIn](https://www.linkedin.com/in/stefan70/recent-activity/all/) | [GitHub](https://github.com/steble70/scriptlab/blob/master/CV-2025_test.ipynb) |
# Certifieringar: [MS-900](https://www.linkedin.com/posts/stefan70_microsoft-365-certified-fundamentals-activity-7132201402134671360-sZQr?utm_source=share&utm_medium=member_desktop&rcm=ACoAABLNm-IBiq5TlsugIMH7rx0wSvX1qkpzei0), [SC-900](https://www.linkedin.com/posts/stefan70_microsoft-certified-security-compliance-activity-7125476344208969728-TL_O?utm_source=share&utm_medium=member_desktop&rcm=ACoAABLNm-IBiq5TlsugIMH7rx0wSvX1qkpzei0)
#
# ---

# %% [markdown]
# ## **Först skapar vi lite testfiler**

# %%
cd ~
# Out:
# C:\Users\StefanBlecko

# %%
mkdir Tidö
# Out:
# A subdirectory or file Tid” already exists.

# %%
cd Tidö
# Out:
# C:\Users\StefanBlecko\Tidö

# %%
from pathlib import Path
import random


def createfile(targetdir, name, num=1):
    targetdir = Path(targetdir)
    for _ in range(num):
        filename = f'{name}_ON-D{random.randrange(10000, 99999)}.pdf'
        targetdir.joinpath(filename).touch()

createfile('C:/Users/StefanBlecko/Tidö', 'Alternativ_statistik', 8)
createfile('C:/Users/StefanBlecko/Tidö', 'Desinformation', 5)
createfile('C:/Users/StefanBlecko/Tidö', 'Talepunkter')
createfile('C:/Users/StefanBlecko/Tidö', 'Propagandamaterial', 6)

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 942A-0CD0
#
#  Directory of C:\Users\StefanBlecko\Tid”
#
# 2025-12-31  14:31    <DIR>          .
# 2025-12-31  13:50    <DIR>          ..
# 2025-12-31  14:31                 0 Alternativ_statistik_ON-D19636.pdf
# 2025-12-31  14:31                 0 Alternativ_statistik_ON-D41497.pdf
# 2025-12-31  14:31                 0 Alternativ_statistik_ON-D42884.pdf
# 2025-12-31  14:31                 0 Alternativ_statistik_ON-D59459.pdf
# 2025-12-31  14:31                 0 Alternativ_statistik_ON-D81103.pdf
# 2025-12-31  14:31                 0 Alternativ_statistik_ON-D81406.pdf
# 2025-12-31  14:31                 0 Alternativ_statistik_ON-D85017.pdf
# 2025-12-31  14:31                 0 Alternativ_statistik_ON-D89271.pdf
# 2025-12-31  14:31                 0 Desinformation_ON-D15811.pdf
# 2025-12-31  14:31                 0 Desinformation_ON-D63676.pdf
# 2025-12-31  14:31                 0 Desinformation_ON-D67151.pdf
# 2025-12-31  14:31                 0 Desinformation_ON-D85197.pdf
# 2025-12-31  14:31                 0 Desinformation_ON-D93050.pdf
# 2025-12-31  14:31                 0 Propagandamaterial_ON-D32806.pdf
# 2025-12-31  14:31                 0 Propagandamaterial_ON-D45176.pdf
# 2025-12-31  14:31                 0 Propagandamaterial_ON-D48043.pdf
# 2025-12-31  14:31                 0 Propagandamaterial_ON-D49263.pdf
# 2025-12-31  14:31                 0 Propagandamaterial_ON-D56252.pdf
# 2025-12-31  14:31                 0 Propagandamaterial_ON-D81178.pdf
# 2025-12-31  14:31                 0 Talepunkter_ON-D80561.pdf
#               20 File(s)              0 bytes
#                2 Dir(s)  158ÿ182ÿ436ÿ864 bytes free

# %% [markdown]
# ## **Mayhem.py**
#
# ```python
# # Mayhem.py
# # © Stefan Blecko
# # Version 0.4.2, 2021, 2025
#
#
# import random
# import argparse
# import pathlib
#
#
# def filename_generator():
#     num = list(str(random.random()))[2:]
#     num.append('666')
#     random.shuffle(num)
#     return ''.join(num)
#
# def mystic_message():
#     message = ['Violent torture ', 'Death has arrived ', 'Armageddon ', 'Terror and fright ',
#                'Bleeding corpses ', 'Rotting decay ', 'Anarchy ', 'Violent torture ',
#                'Antichrist ', 'Lucifer ', 'Son of Satan ', 'Pure Fucking Armageddon ',
#                'Pure Fucking Armageddon! ']
#     return message
#
# def math_symbols():
#     special_char = [
#         '+', '-', '*', '÷', '%', '‰', '(', ')', '±', '≡', '=', '≈', '<', '>', '≥',
#         '≤', '√', 'ⁿ', '¹', '²', '³', 'π', '°', '#', '∞', 'µ', 'Σ', '∩', '⌠', '⌡']
#     return random.choice(special_char)
#
# def junkfile_generator():
#     special_char_array = []
#     for spch in range(1, 3500):
#         special_char_array.append(math_symbols())
#     special_char_array.append(mystic_message())
#     random.shuffle(special_char_array)
#     return special_char_array
#
# def number_of_files():
#     return random.randrange(2, 20)
#
# def directory():
#     p = pathlib.Path('.')
#     return p.iterdir()
#
# def main():
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--generate_junk_file', type=int, default=1)
#     parser.add_argument('--random_delete', action='store_true')
#     parser.add_argument('--rename_file', action='store_true')
#     args = parser.parse_args()
#
#     if args.random_delete:
#         for n in range(1, number_of_files()):
#             rnd_pick = random.choice(list(directory()))
#             if rnd_pick.suffix == '.exe' or rnd_pick.suffix == '.py':
#                 pass
#             elif rnd_pick.is_dir():
#                 pass
#             else:
#                 print(rnd_pick, '[Raderad]')
#                 rnd_pick.unlink()
#
#     elif args.rename_file:
#         for item in list(directory()):
#             if item.suffix == '.exe' or item.suffix == '.py':
#                 pass
#             elif item.is_dir():
#                 pass
#             else:
#                 print(item, '[Ändrad]')
#                 item.rename(f'{filename_generator()}' + f'{item.suffix}')
#
#     elif args.generate_junk_file >= 1:
#             for n in range(args.generate_junk_file):
#                 with open(filename_generator() + '.txt', 'x', encoding='UTF-8') as f:
#                     for item in junkfile_generator():
#                         f.write(''.join(item))
#             f.close()
#     else:
#         pass
#
#
#
# if __name__ == '__main__':
#     main()
# ```

# %% [markdown]
# ## **Jupyter Notebook generering av Mayhem.py med Microsoft Copilot**

# %% [markdown]
# #### **Input (copilot.microsoft.com)**
# Skapa en Jupyter Notebook med flera celler.
# - En Markdown cell med instruktioner om hur man använder *papermill* modulen i Jupyterlab.
# - Analysera sedan Mayhem.py och ersätt *argparse* modulen med *papermill* modulen så att man kan använda skriptet i Jupyterlab. Dela upp skriptet i flera celler. Skriv en kort kommentar hur man kör skriptet

# %% [markdown]
# #### **Copilot**

# %% [markdown]
# **Papermill** är ett Python‑verktyg som låter dig:
#
# - Köra Jupyter Notebooks programmässigt
# - Skicka in parametrar till en notebook
# - Skapa automatiserade pipelines
# - Versionera och reproducera körningar
#
# **Installation**
# ```bash
# pip install papermill
# ```
#
# **Grundidé**
#
# Du markerar en cell som *parameters*:
#
# ```python
# # Parameters
# my_value = 10
# ```
#
# Sedan kör du notebooken med nya värden:
#
# ```bash
# papermill input.ipynb output.ipynb -p my_value 42
# ```
#
# **Varför använda Papermill här?**
#
# Vi ersätter `argparse` i Mayhem.py med Papermill‑parametrar så att skriptet kan köras direkt i JupyterLab utan kommandoradsargument.
#
# Det gör skriptet:
# - enklare att testa
# - mer interaktivt
# - mer reproducerbart

# %%
import random
import pathlib

def filename_generator():
    num = list(str(random.random()))[2:]
    num.append('666')
    random.shuffle(num)
    return ''.join(num)

def mystic_message():
    return [
        'Violent torture ', 'Death has arrived ', 'Armageddon ', 'Terror and fright ',
        'Bleeding corpses ', 'Rotting decay ', 'Anarchy ', 'Violent torture ',
        'Antichrist ', 'Lucifer ', 'Son of Satan ', 'Pure Fucking Armageddon ',
        'Pure Fucking Armageddon! '
    ]

def math_symbols():
    special_char = [
        '+', '-', '*', '÷', '%', '‰', '(', ')', '±', '≡', '=', '≈', '<', '>', '≥',
        '≤', '√', 'ⁿ', '¹', '²', '³', 'π', '°', '#', '∞', 'µ', 'Σ', '∩', '⌠', '⌡'
    ]
    return random.choice(special_char)

def junkfile_generator():
    special_char_array = []
    for spch in range(1, 3500):
        special_char_array.append(math_symbols())
    special_char_array.append(mystic_message())
    random.shuffle(special_char_array)
    return special_char_array

def number_of_files():
    return random.randrange(2, 20)

def directory():
    p = pathlib.Path('.')
    return p.iterdir()

# %%
# Parameters
generate_junk_file = 10
random_delete = False
rename_file = False

# %%
if random_delete:
    for n in range(1, number_of_files()):
        rnd_pick = random.choice(list(directory()))
        if rnd_pick.suffix in ['.exe', '.py']:
            pass
        elif rnd_pick.is_dir():
            pass
        else:
            print(rnd_pick, '[Raderad]')
            rnd_pick.unlink()

elif rename_file:
    for item in list(directory()):
        if item.suffix in ['.exe', '.py']:
            pass
        elif item.is_dir():
            pass
        else:
            print(item, '[Ändrad]')
            item.rename(f'{filename_generator()}{item.suffix}')

elif generate_junk_file >= 1:
    for n in range(generate_junk_file):
        with open(filename_generator() + '.txt', 'x', encoding='UTF-8') as f:
            for item in junkfile_generator():
                f.write(''.join(item))
    print(f"Skapade {generate_junk_file} junk‑filer.")
# Out:
# Skapade 10 junk‑filer.

# %%
# %pycat 5442352790666409289.txt
# Out:
# =≈#∩±≡⌡=³≡≤≤>=÷ⁿ‰°√≡⌠+±≤<±(=(≈=%≥√Σ>¹≡∞≤°²µ<<µ%=%‰²%⌠π+³#²<%<Σ∞ⁿΣ=¹∩-≈#∩≈Σπ‰=°∞<∞≤÷⌡¹³‰°√ⁿ()≡%÷+ⁿ-⌡‰µ‰≡²*¹=µ(±-≡>ππ#*²÷∞*%(Σ÷π≤°≡)%±⌠√Σ≥+µ¹⌠∩¹÷⌠√+-->°=#√Σ¹π<#≥²‰⌠)ⁿ-*±>÷≈π‰=((‰%)±⌡-≡+≤≡√‰+#%+π-∩÷∞²±±÷#+⌡∩(*π÷πµ⌡±∩°#±∩%≈-<(÷¹³)%(*⌡**±²°³÷÷√÷%µ-=¹∞(²√¹√≤‰≡²µ°²µ⌠%∞ⁿ>√∩+>±##-²=°±+≥°(⌡⌡*µ%#≤*(³∩°°³√(<*=¹(³>⌠≈⌠≥-÷-<π³Σ≈±-π>+∞≡>‰⌠≤³>µ≈≤µ#µ-°>#√³≤=√∩µπµ)≡<²¹°<%µµ>°Σ⌠⌡¹>=³⌡=≡≈)π≤∩<%µⁿ≥>≈∞≈ⁿ)÷¹µµ⌡)°µ÷>±±°Σ≡≈≥≥)⌡³πµ<⌠ⁿⁿⁿΣ∩≈±¹µ(²ⁿπ³*%ⁿ∞³⌠Σ°=<±°∩≤≡≥#≤∩¹∞-±ⁿπ+ⁿ⌡³³≈ⁿ->°(≡÷-⌠=(*⌡³≤¹)⌠‰²√‰³⌠≥µ¹*‰<∞>-³≤²²≤*¹)∞²³µ⌠∩≈∩*≥⌠ⁿ¹⌠≤±≡+⌠³³²²*=(µ±⌡±πµ÷⌡(%³>∩π≤∩%%÷≡=µ-≈ⁿ≥π∩⌡°√%÷√≥%ⁿ>*≡²π(=≤Σ∩>∩>≡∞≡=π≡ππ≤°≡√µ+⌡*°⌡°µ°÷=Σ≥≡≡#°<%Σ-∞µ(∩>≈∞‰³#⌠π+°Σ÷‰ⁿ<≥≥-°∞+±∞>≈÷<≈µ(¹∩‰‰±<≡∞π¹∩∞³+²⌡∩²>-)*=-<⌡√(∞‰≤≈Σπ>+⌠=ⁿ√≤*¹+‰-÷*-÷±=-≤#≡#%¹µⁿ°≥(ⁿ≈∞≡≡<¹(%⌡≈∞**⌡±÷³ⁿ≤π°≤∩π-²≥)%≤√°≤≈(%≥÷¹π>)∩>¹∞πΣ∞√≤∩³∩%()⌡+∞µ-∩#¹²(±⌡)⌡²°Σ%÷*⌡‰‰)<Σ≡#⌠#Σ>(√≈(⌡≈±∩²%⌡#-‰∩≥Σ√≡°√‰#≤√≡*%∩≡²(∩*>²⌠∞ⁿΣ%‰≈°>⌡∞µ‰>≤≥³<¹π⌡√µπΣ²≡≈µ÷>‰%¹µ¹-µ⌠≡±)-π°ⁿµ=÷≡‰±Σ≈²⌡¹√Σ³(²)-µ√≥∩Σ#¹√)))ΣΣΣ>√²≥≤)µ=∩¹-≥>(ⁿ±√π-³∞≡⌡√∩ⁿ≈∞π√%µ≈≈³πµµ≈°(ⁿµΣ)¹>π⌡π≡°))*°∩#³ⁿ³¹-πΣ÷√πΣ∩⌡‰≤°≈±%³¹((⌡<⌠=∞)%#¹µ*µ±∩²‰√÷#(∩#±=Σ-<≈*∞)+%<⌠≤³∩√<))#≈‰(->)°=‰√≡²>²*‰√±≤ⁿⁿ⌡≈±∩√°π%(¹*∞≈*≥=⌠√÷+(<∩÷>²≤³°±²≡√³-≤ⁿ∩*≥³π∞+³ⁿ∞±≡≤÷<=³∩><⌠°⌡>¹√=Σ%%≤≥≤-<≤+-%%%¹⌡∩⌡ⁿ≥ⁿ±≤≈∞<°<∞≥³¹)≈#¹²(÷π≥#-(⌡>⌡πΣΣ)%¹+°‰+÷≤≡≥≥≡∩°³≡≈⌡≥⌡‰ΣⁿΣ>*≥>√¹ππ⌡¹⌡³%)∩%±-÷%>(<≡+*µ>≡>>≤=°≥%≤⌡∩≈‰(ΣΣ≡)±>²≡±≡³¹¹+>±π÷(¹⌡ⁿ%(⌠∞⌠≡%∩(⌠*⌠²µ*¹∩)⌡≡(+≡÷+∩ⁿ±#≡∞⌡±#≥⌠(µ⌠√∩∞°>*≡<≈>(≤Σ¹π⌡÷≥∩÷¹³=∩‰∞⌠°±÷(≈<+±√µ⌠‰πµ-#≈‰(<‰π÷≥∞‰⌠√=-°)#≈≡>≡≥(°*¹)≈)ππ⌡²≡°°±%°²÷±≡≡≤>³Σ∞°+ⁿ+‰%⌠+¹<÷)+>≡<ⁿπⁿ*²*-°-<≤≡²≤°²≡#‰∩=‰°∩≥≈⌠≤≈∞=°±ΣΣ(÷≡°¹(+*³°≤π∩<⌠±≤°³ππ⌡*Σ=%Σπ*√#ⁿ°¹(°÷+÷‰¹*±¹≤>³-³-µ÷‰∞≥≤#*²-<%#%µⁿ≤¹>)⌡∞≥*²³*+≈²≈**=∩<≈≡≡±≥°⌠∩³µ)²∩>µ⌡⌡==#ⁿ#≈(¹Σ∩∩∩ⁿ-)+)÷>µπ²%%+-≥-≡≈‰≡±⌡-)Σ∩√√÷<Σ²¹≡³##=-%√÷)±∩<Σ√π)⌠²°)*ⁿ=(⌡±∩∩#)¹∩√ⁿ-³∞Σ(=<<%∩⌡*≈Σ(##=≥)‰³-¹≤³#)√±*#∞÷-≤≈∩°±²‰÷=°∞%π⌡*)°⌠)π+±Σ-°)≤³°≤⌠¹ⁿ∩%°≡⌠π-⌡-≤<¹ⁿµ√∩ⁿ÷µ÷±°≡(π√π≡≈±⌠%*∩÷≡÷÷=∩<*ⁿ∞*(≈*³-³²µ∩(µ+#√≈)÷>≥³<≥)µ∩√µ≤¹%³Σ∞µ≤%±±³≡√⌠÷ππ²√∩³∞()=≡÷°*≈÷²#²÷∩(π°¹=²²√<=²≤⌡±>>≡±¹π-(≡#+=≈³#)‰¹#≤‰ⁿ≤³%<≡#≤)⌡*≡-≡µ√≡¹²°*°≤(≡*#<+>ⁿ⌡>∩=÷ⁿ(±±>=‰⌠⌡÷√°°√)+²≡±‰∞>²≥√<²∩⌠⌠²÷±-≡‰≈(π<+⌡≤)°µ∩³≥)≡>≡⌡%√)≥°Σ-≡Σ°Σ=µ÷)%µ≥-²°‰√≈≥⌡¹%⌠#≤≤<⌠π÷<-÷<π%≤ⁿ<⌠(+³(÷Σ²∩-‰#=#≈%π(‰#‰-‰=-⌠ⁿ³Σ∞#Σ*±)=⌠¹+±*³<⌠)√≈‰Σ∩ⁿ≡%√µ#∩>¹π³⌡<-≥(√<≈¹≈‰#°µ±≈°‰°±)⌡‰≤∩≈⌡=≈³#≥⌠)µµ√⌠µ÷≡#³≡÷±≡±≥⌠≈ⁿ³±(÷µ±≡÷≥≡<°>>⌡¹>³*¹≈÷(±(ⁿ∩≡∩²¹∞(%)(#%≡)⌠≥-(∩÷+#∩>±π÷‰≥≡)(µµ-+≡*‰<²⌡≡<√∩(%+%ⁿ⌠÷πµ≈Σ*≥≈√>≈‰≤≥-+>²∩²*-π⌡(-±)#≈<#∞%*≥°=#>²µ≤±≡>≡#≤°±⌡>ⁿ#+≥≥‰+√²*±÷ⁿ%ⁿ+³π⌠²%²)±∞°√%∩‰¹∩)≥³∞π³%µ÷°⌠√µ‰=π∞±(>π+¹‰Violent torture Death has arrived Armageddon Terror and fright Bleeding corpses Rotting decay Anarchy Violent torture Antichrist Lucifer Son of Satan Pure Fucking Armageddon Pure Fucking Armageddon! ≈√(π))<ⁿ√*-=*∞ⁿ³++∩≥π#≡÷>+=-°²⌡<±<=°++*≡‰*÷°≤≤µ√%≈⌠+¹%√%)²+≥≥≤ⁿ≤π∩)(⌡≈(=ⁿ√ⁿ>³*>∩=ⁿ>π¹-√>≥√π%#≤‰*-³#%Σ<∩>+⌠<)≥(*ⁿ∩≥*π⌡Σ⌠√<>%Σ#∩)*)°∩÷÷)ⁿ+<≡≡⌠²=)±πⁿπ=µ∩±<±≤<Σ‰(∞²<∩ⁿ≥°≥√≡⌠>≈∩⌠‰≥÷≥<⌡*±(*‰ⁿ≡√ⁿ⌡⌠±≤πΣ(<÷<)⌠π-%π<²¹³√ⁿ±(≡+=÷∩#%#≡°³>π≡≥÷ⁿ#-≥÷∩°)ⁿ⌡∞°≈)÷∞(*#°≈->≡‰ⁿ≡Σ‰ⁿ∩≥%÷≥√∩)≥%>ⁿ=√µ⌡==(√°⌡π≈>²=÷≥<³>¹⌠±≥∩#∞=≤∩+#∞±°÷≤+⌠÷#µ≥‰≈°∩µπ-ⁿ%+≤≡∩Σ+-*ⁿ%≈-)√π#∞+≥‰²³⌡µ>Σ±≤⌠(-≈=∩≥-=#π÷⌡÷>²-+≈π#*⌠+Σ#√¹-<≥Σⁿ°∩*⌡-‰>⌠¹#-±∞(+÷*+<±∩>#∞#³+‰³∞Σ±²*-)±⌡±*ππⁿ⌡÷%%µ%¹<#¹)÷ⁿ*ⁿ∩≥³ⁿ<(-ⁿ≡⌠>=Σ≈->=+°³π*>√≡#+≥≡)Σ≈≤(ⁿ≤µπ±≈∩≥∞³∞²%<≡⌠≥∞<>∩-≡≡-⌡≤≥⌠⌠≈∩⌡Σ=Σ=≡¹=≈-*³<²⌡√=≥<Σ∩²)π≤⌡%≤⌡(≥#°≥π+ππ‰÷+*>≈=≥(∞=°*≈°ΣΣ(ⁿΣⁿ+=‰∞±⌡Σ*≥±°⌡≡°+%%)≡⌡µ-±π>≡≈=≈≈%#-(±≤∩±√#±°=π=³Σ%⌠⌡³¹=(≥-πµ∩⌠∩<ⁿ‰²%)¹≥²≤ⁿ≤√‰≈+√±-³*≈√Σ°<≥>∩=²><³%¹±)∩≥#∞µⁿ∞*√‰)>=³≤²<π+µ¹(²¹⌡⌠≥*--µ²⌡<)÷Σ∞>+∩π(²³≡⌡³-⌠≈µ#⌡µ-÷)*≡%⌡*⌠⌠ⁿ⌡°<(≡%¹<ⁿ≡#ⁿ³¹³√%(µ(+)√°³≡∞°≥>²≥(⌡¹⌠>√π+π÷≥ⁿ*µ+#Σ+≥√π><÷⌠ⁿ⌡³≡µΣ°⌡√⌠Σ⌠#√-π²³⌡≤≈+√*>(±²ΣΣ=*³ππ∞³¹≤³≤π‰³%(*∞#≤²√-÷⌡√±÷Σ=≤-ⁿ≈‰Σµ±Σ‰±⌠(ⁿ≥∞≡%)∞⌠⌠≈³ⁿ⌠√-µ¹√÷≥≥#(µ÷≥≡∩)±²‰<÷‰-≈°-)÷⌠<⌡µ≡¹%≤(∞∞÷≈(²+≡√∞<#=µ¹⌡√≥#∩‰)¹≥)≤ⁿ>π⌠->ⁿ%Σ<π<=+≈µ≥%÷++¹²*∩⌡¹-⌡¹⌡≤--∞µⁿ°µ‰⌡∩≤%>π√->‰µ%≤÷≡µ⌡‰±π²µⁿ∩±>%÷>≤²∩±(⌡-ΣΣ∞≥ⁿ≤∞(<≡>√%≡≤²+≥µ≈Σ=<∞(-µ∞>⌡=)∞=(²⌠⌠‰Σ%≥∞+ⁿ∞⌡*¹+²ⁿ√Σ<#µ%>ππⁿ+)%≈⌠‰>µ°=⌠³=π⌡<⌡∩≤∩≡÷=²°≡√‰#±µ+*%#√=⌠∞≤#³≤+±*%≈-⌠≥¹‰²+µ≈⌠≤⌠>∞⌡°>∩≈#µ°≡≈=‰±≥>∩⌡%⌠+⌠√∞∩⌠¹µ+*‰∞∩>¹√<µ+µΣ±ⁿ⌠%Σ∩⌡³≤<*≡²³≈⌠∞<+≈(≡≈π<*)³=°%°‰÷=°<±≤∞≥≡¹¹)ⁿ‰‰<π#)°≈ⁿ

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 942A-0CD0
#
#  Directory of C:\Users\StefanBlecko\Tid”
#
# 2025-12-31  14:32    <DIR>          .
# 2025-12-31  13:50    <DIR>          ..
# 2025-12-31  14:31                 0 0315166607103588857.pdf
# 2025-12-31  14:31                 0 117613985866666644.pdf
# 2025-12-31  14:31                 0 1427055403071666745.pdf
# 2025-12-31  14:31                 0 166621363353566092.pdf
# 2025-12-31  14:31                 0 28523834928366645087.pdf
# 2025-12-31  14:31                 0 330535042226669561884.pdf
# 2025-12-31  14:31                 0 3501360561514766675.pdf
# 2025-12-31  14:31                 0 38626701666657771360.pdf
# 2025-12-31  14:31                 0 4166661752653991555.pdf
# 2025-12-31  14:31                 0 53614680133533666667.pdf
# 2025-12-31  14:32             7ÿ355 5442352790666409289.txt
# 2025-12-31  14:32             7ÿ310 56666709433478476733.txt
# 2025-12-31  14:32             7ÿ313 5750288977351086665.txt
# 2025-12-31  14:32             7ÿ319 58749220225666103558.txt
# 2025-12-31  14:31                 0 643896229132805606663.pdf
# 2025-12-31  14:31                 0 66309481066662972397.pdf
# 2025-12-31  14:31                 0 66658977450314185025.pdf
# 2025-12-31  14:31                 0 6666819648649468046.pdf
# 2025-12-31  14:31                 0 6667819033989757320.pdf
# 2025-12-31  14:32             7ÿ281 7152028647666557556.txt
# 2025-12-31  14:32             7ÿ352 7303257001666552365.txt
# 2025-12-31  14:32             7ÿ309 74514979406245666963.txt
# 2025-12-31  14:31                 0 7483269627196669041.pdf
# 2025-12-31  14:31                 0 7635226663252479231.pdf
# 2025-12-31  14:31                 0 81666655779052610418.pdf
# 2025-12-31  14:32             7ÿ368 8300095717266604429.txt
# 2025-12-31  14:32             7ÿ312 86666977667536599071.txt
# 2025-12-31  14:31                 0 9166687281556721827.pdf
# 2025-12-31  14:31                 0 9202166630000569985.pdf
# 2025-12-31  14:32             7ÿ338 9985582225758113666.txt
#               30 File(s)         73ÿ257 bytes
#                2 Dir(s)  158ÿ184ÿ710ÿ144 bytes free

# %% [markdown]
# **Så kör du skriptet**
#
# 1. Ändra värdena i *Parameters*-cellen:
#    - `generate_junk_file = 5`
#    - `random_delete = True`
#    - `rename_file = True`
#
# 2. Kör notebooken uppifrån och ned.
#
# 3. Om du vill köra notebooken med Papermill från terminalen:
#
# ```bash
# papermill Mayhem.ipynb output.ipynb -p generate_junk_file 10
# ```
#
# Du kan även kombinera parametrar:
#
# ```bash
# papermill Mayhem.ipynb output.ipynb -p random_delete True
# ```
#
# Notebooken fungerar nu som ett interaktivt och automatiserat verktyg för att generera, radera eller döpa om filer.
